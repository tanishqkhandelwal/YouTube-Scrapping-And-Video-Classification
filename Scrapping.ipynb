# %%
import requests
import json
import pandas as pd

# %%
token = "AIzaSyAbSmFU0xrdQemddrfT8PSYdNxVBF3DiwQ"

category = ["Travel Blogs", "Science and Technology", "Food", "Manufacturing", "History", "Art and music"]
videoId = []
title= []
description= []
Category= []
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[0]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[0])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[0]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[0])

token = "AIzaSyAP0yKUjdSR5P2n9Wp9Adh1qG5rjgqadAI"        
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[0]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[0])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[0]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[0])

# %%
token = "AIzaSyDyk9vhqiE5S5csMp5vSHu7QXAx6sFSsak"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[1]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[1])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[1]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[1])

token = "AIzaSyBMmp8pbpwqyHApYeGJyjLMMkLZaLebVt0"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[1]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[1])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[1]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[1])

# %%
token = "AIzaSyCfWwZEr1rpN_lbzBJ0wmzCe6G31OG0Jgo"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[2]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[2])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[2]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[2])

token = "AIzaSyA9qBgEeT96mE7TsyXTLUNvPG97_ZHvTU8"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[2]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[2])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[2]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[2])

# %%
token = "AIzaSyA0NQWQJXZs8xbu46WmYtQKxogPB63qJts"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[3]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[3])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[3]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[3])

token = "AIzaSyBEW8x6aZm-89MiIpBl-3F500XgWzH0U8w"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[3]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[3])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[3]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[3])

# %%
token = "AIzaSyAqDqlb9_yC36mQ8kmFPN6ujUff5odh6lk"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[4]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[4])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[4]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[4])

token = "AIzaSyBfVopru-zQW7K_1zKajAEenA8_xlYhWYo"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[4]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[4])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[4]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[4])

# %%
token = "AIzaSyDgs4sYIfiOoEtkr_ZQ8n1fpO1v4ujlf6o"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[5]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[5])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[5]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[5])

        
token = "AIzaSyAQJhPrTYClgdk8-PJJgOICSN1MhmXCbsY"
r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[5]+"&order=viewCount&key="+token)
json_data = json.loads(r.text)
nextPageToken=json_data.get('nextPageToken')
for i in range(len(json_data['items'])):
    videoId.append(json_data['items'][i]['id'].get('videoId'))
    title.append(json_data['items'][i]['snippet']['title'])
    description.append(json_data['items'][i]['snippet']['description'])
    Category.append(category[5])

for j in range(18):
    r=requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q="+category[5]+"&order=viewCount&pageToken=" + nextPageToken + "&key="+token)
    json_data = json.loads(r.text)
    nextPageToken=json_data.get('nextPageToken')
    for i in range(len(json_data['items'])):
        videoId.append(json_data['items'][i]['id'].get('videoId'))
        title.append(json_data['items'][i]['snippet']['title'])
        description.append(json_data['items'][i]['snippet']['description'])
        Category.append(category[5])

# %%
df = pd.DataFrame(list(zip(videoId, title, description, Category)), 
               columns =['videoId', 'title','description','Category'])
df.to_csv('data.csv',index=False)
